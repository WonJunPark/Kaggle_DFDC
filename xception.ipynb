# %% [markdown]
# # Xception Classifier w/ FFHQ - Training - LB: .555

# %% [markdown]
# <h4> 본 커널은 캐글에 공유된 https://www.kaggle.com/greatgamedota/xception-classifier-w-ffhq-training-lb-537 의 내용을 기반으로 작성되었습니다. </h4>

# %% [markdown]
# ## 1. Data Preprocessing
#
# ### 1.1 Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from tqdm import tqdm,trange
from sklearn.model_selection import train_test_split
import sklearn.metrics

import torch
import torch.nn as nn
import torch.nn.functional as F

import warnings
warnings.filterwarnings("ignore")

# %%
print("PyTorch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())
# Out:
# PyTorch version: 1.4.0+cu92
# CUDA version: 9.2
# cuDNN version: 7201

# %% [markdown]
# ### 1.2 Load Data

# %%
df_train = []

# total = 50
df_train_num = 47   # 0~46
df_val_num = 3      # 47~49

df_trains = []
df_vals = []

for i in range(df_train_num):
  s = 'input/deepfake/metadata'+  str(i) +'.json'
  deepfake = pd.read_json(s)
  df_trains.append(deepfake)

for i in range(df_val_num):
  s = 'input/deepfake/metadata'+ str(df_train_num + i) +'.json'
  deepfake = pd.read_json(s)
  df_vals.append(deepfake)

nums = list(range(len(df_trains)+1))
LABELS = ['REAL','FAKE']
val_nums=[47, 48, 49]

# %%
df_trains[0]
# Out:
#           owxbbpjpch.mp4 vpmyeepbep.mp4 fzvpbrzssi.mp4  htorvhbcae.mp4  \
# label               FAKE           REAL           REAL            FAKE
# original  wynotylpnm.mp4            NaN            NaN  wclvkepakb.mp4
# split              train          train          train           train
#
#           fckxaqjbxk.mp4  sphirandia.mp4  vsmadeuczx.mp4  ohaqlzfnuv.mp4  \
# label               FAKE            FAKE            FAKE            FAKE
# original  vpmyeepbep.mp4  jawgcggquk.mp4  qarqtkvgby.mp4  sttnfyptum.mp4
# split              train           train           train           train
#
#           komngcqveq.mp4  iafvzgpbix.mp4       ...        dflpzzixje.mp4  \
# label               FAKE            FAKE       ...                  FAKE
# original  kqlvggiqee.mp4  lzbmwwejxb.mp4       ...        nhsijqpoda.mp4
# split              train           train       ...                 train
#
#          vmxfwxgdei.mp4  jgzwhkcrcc.mp4  nyxrmccdss.mp4 aayrffkzxn.mp4  \
# label              REAL            FAKE            FAKE           REAL
# original            NaN  jytrvwlewz.mp4  jzupayeuln.mp4            NaN
# split             train           train           train          train
#
#           hectzcuzdv.mp4  yxkbjxmtzr.mp4  wkdnagybtb.mp4  fonrexmbzz.mp4  \
# label               FAKE            FAKE            FAKE            FAKE
# original  vtunvalyji.mp4  sttnfyptum.mp4  jytrvwlewz.mp4  fufcmupzen.mp4
# split              train           train           train           train
#
#           etychryvty.mp4
# label               FAKE
# original  uqtqhiqymz.mp4
# split              train
#
# [3 rows x 1334 columns]

# %% [markdown]
# ### json file
# ![title](img/metadata.png)

# %% [markdown]
# ### 1.3 Labeling

# %%
def get_path(num,x):
    num=str(num)
    if len(num)==2:
        path='input/deepfake/DeepFake'+num+'/DeepFake'+num+'/' + x.replace('.mp4', '') + '.jpg' #jpg 파일만 불러오기
    else:
        path='input/deepfake/DeepFake0'+num+'/DeepFake0'+num+'/' + x.replace('.mp4', '') + '.jpg'
    if not os.path.exists(path):
       raise Exception
    return path

# %%
# Labeling
# json 파일과 img 파일을 매칭
paths=[]
y=[]
for df_train,num in tqdm(zip(df_trains,nums),total=len(df_trains)):
    images = list(df_train.columns.values)
    for x in images:
        try:
            paths.append(get_path(num,x))
            y.append(LABELS.index(df_train[x]['label']))
        except Exception as err:
            #print(err)
            pass

val_paths=[]
val_y=[]
for df_val,num in tqdm(zip(df_vals,val_nums),total=len(df_vals)):
    images = list(df_val.columns.values)
    for x in images:
        try:
            val_paths.append(get_path(num,x))
            val_y.append(LABELS.index(df_val[x]['label']))
        except Exception as err:
            #print(err)
            pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 47/47 [00:10<00:00,  4.55it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  4.58it/s]

# %%
print('y : ',len(y))
print('val_y :',len(val_y))
# Out:
# y :  104890
# val_y : 7366

# %% [markdown]
# ![title](img/dataset_len.png)

# %%
paths
# Out:
# ['input/deepfake/DeepFake00/DeepFake00/vpmyeepbep.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/fzvpbrzssi.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/htorvhbcae.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/fckxaqjbxk.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/sphirandia.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ohaqlzfnuv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/komngcqveq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/iafvzgpbix.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uaukglhmje.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/syxobtuucp.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/dtjcyzgdts.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/viuioldtnu.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wnaweyzlqh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ejhhdlzpjg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/sxyrkshzsg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uvfkppqsjy.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kedahvzait.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/idczhqbbqz.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/clzkcmoyhb.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/vpjfmetsvn.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ztwlbdwyni.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/jaurxwocly.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/jkxjvuioek.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/dhjnjkzuhq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xcruhaccxc.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/rfpjsloxzg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kmcdjxmnoa.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/vvwuqslvnq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/rpxnyljmsf.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/txxungvxms.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ihnhxathkq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/lobxktzhbg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/slhinthqcq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/hqzwudvhih.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xpzfhhwkwb.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/sglzgdcjkb.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xxvwbfmgzy.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/dtmlspmqqp.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/hsxrmrcaqh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ykbhmueovi.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/inzrlbgtul.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xtcbnasaew.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kgfcupxgur.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nkojmntmdg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/btizoxwqwp.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/zvsivkdkak.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/yjllqhbmke.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ygknkubeyb.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wkczijuamz.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/dolynaukae.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/eisofhptvk.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xymeodlrhb.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/rnpefxwptv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/gilzdnbpep.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/vamicuaopj.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/oypqzdrhcr.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nglitpseyp.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/onknhowfqb.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/izjvqhjokl.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wirblaouzv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/hgjdosshpt.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/qjvjkojjkl.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/oobmorozgk.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/dsiirbwwyt.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/buzdtxdyid.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/aymlynzeni.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/scpglaliyh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wwvykizoms.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uyhqrokmfe.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/imndwwlfui.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/rpnetwqgqz.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/stgusxhcta.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/oibtsgqujh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/iazovjywij.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/lxnqzocgaq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/sttnfyptum.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/eurhttghny.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kdiokpezzi.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/gbgtzspdnv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/tyijytqowe.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wvjtrmduky.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/hqcrauawma.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/chzqptmqxv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kkxgqvpusd.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/tvjlounpor.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/tkcuhfhdzs.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/sufvvwmbha.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uklvqsnxgv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ngyoubuxyf.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wpysxggnok.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ocveomkblt.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/qjwomijmcb.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xdbnawbnvf.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/drmtvuyoam.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xugmhbetrw.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/lblzsydwit.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/euzlhrwolz.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/yhchnvjcok.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uqtqhiqymz.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/fgbopxbkam.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kkhrtmftlq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/hbdvyzpqny.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/khfyqlxazq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/pxgzahcusu.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/cvycgtwfsi.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/keuvybqsbr.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/hjxckindzx.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/espkiocpxq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/cvdrzlkwdf.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uiaubrlxyl.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/
.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/bqamrsyvnf.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/yfnvwhnofw.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xbtmhdgcie.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/llseqxuobs.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uipygodqdq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xjsovchfkg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nweufafotd.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/cxgsjamupo.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nxzgekegsp.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nqrcttpsme.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wgddfhuvoq.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/qhugrooovy.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wezyzowkwh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ovzegelwbu.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/gzkggvloao.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/eckloytegm.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/oopzotineh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kgcbejdwal.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/iyhkhsdhma.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ybnucgidtu.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/eppmwpntfi.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/jfvsrcfame.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/dibwmyrpql.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/rvaliysfnr.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ijgcwhjkua.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/vzocjdjdcg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nbibouebku.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/svtocotxob.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ktvvpqqupl.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xhtppuyqdr.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xbokoalmlv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/gjjpzsgigh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/omizcfnsic.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xjidmljhxe.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/zqtvyuoabj.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nmgnxptofk.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nwdhwzcpoi.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kxzgidrqse.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ddtbarpcgo.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/sgyrvomqcf.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/qhsehzgxqj.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/chqqxfuuzi.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/zwsbdiyrpg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/hhyxweyjlt.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/dpevefkefv.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/furvgnwfln.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/kadzgvxsii.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/cdyotmvujc.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/xiriffwqri.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/pjkmbiofvd.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/bldeizqycp.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/petmyhjclt.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/opvqdabdap.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/mtfhqqlkgs.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wiqnwcizhc.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/jakregbmuf.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/mlruidevki.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/oxljjggptm.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nlurbvsozt.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/oolnekhvhx.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/pqexbhcasg.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/ulkrhrktaz.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/zbpwazdhtz.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/gbatfzbsjs.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/pgzduygsyr.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/tmgdhykjbo.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/vgdwxafmnp.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/yotgejovqt.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/rmchuqjjwr.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/wsxxdlhnhh.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/qwocosaxwe.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/nqfpecqeab.jpg',
#  'input/deepfake/DeepFake00/DeepFake00/uxchsxvvme.jpg',
#  ...]

# %% [markdown]
# ### 1.4 Random Sampling

# %%
# 컬러 이미지를 읽어오는 함수
def read_img(path):
    return cv2.cvtColor(cv2.imread(path),cv2.COLOR_BGR2RGB)

# X,y 데이터셋을 섞어줌
def shuffle(X,y):
    new_train=[]
    for m,n in zip(X,y):
        new_train.append([m,n])
    random.shuffle(new_train)
    X,y=[],[]
    for x in new_train:
        X.append(x[0])
        y.append(x[1])
    return X,y

# %%
import random
def get_random_sampling(paths, y, val_paths, val_y):
  real=[]
  fake=[]
  # train 데이터의 경로와 y값을 받아 real과 fake로 분류
  for m,n in zip(paths,y):
      if n==0:
          real.append(m)
      else:
          fake.append(m)

  # fake=random.sample(fake,len(real))
  # paths list에 경로를 담고, y에 real과 fake 여부를 담음
  # path와 y값을 매칭시켜 정리
  paths,y=[],[]
  for x in real:
      paths.append(x)
      y.append(0)
  for x in fake:
      paths.append(x)
      y.append(1)

  # validation 데이터도 위와 마찬가지로 real과 fake를 나누어줌
  real=[]
  fake=[]
  for m,n in zip(val_paths,val_y):
      if n==0:
          real.append(m)
      else:
          fake.append(m)

  # fake=random.sample(fake,len(real))
  val_paths,val_y=[],[]
  for x in real:
      val_paths.append(x)
      val_y.append(0)
  for x in fake:
      val_paths.append(x)
      val_y.append(1)

  # deepfake 경로안에 이미지를 불러옴
  X=[]
  for img in tqdm(paths):
      X.append(read_img(img))
  val_X=[]
  for img in tqdm(val_paths):
      val_X.append(read_img(img))


  # ffhq 데이터 사용
  # https://github.com/NVlabs/ffhq-dataset 에서 구글 드라이브로 공유
  # Balance with ffhq dataset
  ffhq = os.listdir('input/thumbnails128x128')

  X_ = []

  ffhq_path = []
  for file in ffhq:
    main_path = f'input/thumbnails128x128/{file}/'
    sub_path = os.listdir(main_path)
    for s in sub_path:
      p = main_path+s
      ffhq_path.append(p)
        
  # ffhq 데이터를 불러와 150*150으로 resize
  # 해상도를 높이면 성능이 향상된다는 피드백이 있음
  for file in tqdm(ffhq_path):
    im = read_img(file)
    im = cv2.resize(im, (150,150))
    X_.append(im)
   

  # deepfake의 fake와 real의 비율을 ffhq를 사용하여 맞춤
  # training set과 validation set을 1:1로 맞추기 위해선 
  # 각각 real data 70,806개, 4850개가 필요함
  # ------------------------------------------
  # ffhq 데이터는 69,534개이므로 (원래는 70,000 일부 누락됨)
  # training set 과 valudation set 64684 : 4850으로 나누어서 추가
  for i in range(64684):
    X.append(X_[i])
    y.append(0)
  del X_[0:64684]
  for i in range(4850):
    val_X.append(X_[i])
    val_y.append(0)

  X, y = shuffle(X,y)
  val_X, val_y = shuffle(val_X,val_y)

  return X, val_X, y, val_y

# %%
from torch.utils.data import Dataset, DataLoader
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

class ImageDataset(Dataset):
    def __init__(self, X, y, training=True, transform=None):
        self.X = X
        self.y = y
        self.transform = transform
        self.training = training

    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        img = self.X[idx]

        if self.transform is not None:
          res = self.transform(image=img)
          img = res['image']
        
        img = np.rollaxis(img, 2, 0)
        # img = np.array(img).astype(np.float32) / 255.

        labels = self.y[idx]
        labels = np.array(labels).astype(np.float32)
        return [img, labels]

# %% [markdown]
# ## 2. Model Build

# %% [markdown]
# ### 2.1 Xception model load

# %%
# !pip install pytorchcv --quiet
from pytorchcv.model_provider import get_model
model = get_model("xception", pretrained=True)
# model = get_model("resnet18", pretrained=True)
model = nn.Sequential(*list(model.children())[:-1]) # Remove original output layer
# Out:
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
model[0].final_block.pool = nn.Sequential(nn.AdaptiveAvgPool2d(1))
# model[0].final_pool = nn.Sequential(nn.AdaptiveAvgPool2d(1))

# %%
from torchsummary import summary

# %%
summary(model,(3,150,150))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 74, 74]             864
#        BatchNorm2d-2           [-1, 32, 74, 74]              64
#               ReLU-3           [-1, 32, 74, 74]               0
#          ConvBlock-4           [-1, 32, 74, 74]               0
#             Conv2d-5           [-1, 64, 72, 72]          18,432
#        BatchNorm2d-6           [-1, 64, 72, 72]             128
#               ReLU-7           [-1, 64, 72, 72]               0
#          ConvBlock-8           [-1, 64, 72, 72]               0
#  XceptionInitBlock-9           [-1, 64, 72, 72]               0
#            Conv2d-10          [-1, 128, 36, 36]           8,192
#       BatchNorm2d-11          [-1, 128, 36, 36]             256
#         ConvBlock-12          [-1, 128, 36, 36]               0
#            Conv2d-13           [-1, 64, 72, 72]             576
#            Conv2d-14          [-1, 128, 72, 72]           8,192
#           DwsConv-15          [-1, 128, 72, 72]               0
#       BatchNorm2d-16          [-1, 128, 72, 72]             256
#      DwsConvBlock-17          [-1, 128, 72, 72]               0
#              ReLU-18          [-1, 128, 72, 72]               0
#            Conv2d-19          [-1, 128, 72, 72]           1,152
#            Conv2d-20          [-1, 128, 72, 72]          16,384
[-1, 728, 9, 9]           1,456
#     DwsConvBlock-204            [-1, 728, 9, 9]               0
#             ReLU-205            [-1, 728, 9, 9]               0
#           Conv2d-206            [-1, 728, 9, 9]           6,552
#           Conv2d-207            [-1, 728, 9, 9]         529,984
#          DwsConv-208            [-1, 728, 9, 9]               0
#      BatchNorm2d-209            [-1, 728, 9, 9]           1,456
#     DwsConvBlock-210            [-1, 728, 9, 9]               0
#     XceptionUnit-211            [-1, 728, 9, 9]               0
#           Conv2d-212           [-1, 1024, 5, 5]         745,472
#      BatchNorm2d-213           [-1, 1024, 5, 5]           2,048
#        ConvBlock-214           [-1, 1024, 5, 5]               0
#             ReLU-215            [-1, 728, 9, 9]               0
#           Conv2d-216            [-1, 728, 9, 9]           6,552
#           Conv2d-217            [-1, 728, 9, 9]         529,984
#          DwsConv-218            [-1, 728, 9, 9]               0
#      BatchNorm2d-219            [-1, 728, 9, 9]           1,456
#     DwsConvBlock-220            [-1, 728, 9, 9]               0
#             ReLU-221            [-1, 728, 9, 9]               0
#           Conv2d-222            [-1, 728, 9, 9]           6,552
#           Conv2d-223           [-1, 1024, 9, 9]         745,472
#          DwsConv-224           [-1, 1024, 9, 9]               0
#      BatchNorm2d-225           [-1, 1024, 9, 9]           2,048
#     DwsConvBlock-226           [-1, 1024, 9, 9]               0
#        MaxPool2d-227           [-1, 1024, 5, 5]               0
#     XceptionUnit-228           [-1, 1024, 5, 5]               0
#           Conv2d-229           [-1, 1024, 5, 5]           9,216
#           Conv2d-230           [-1, 1536, 5, 5]       1,572,864
#          DwsConv-231           [-1, 1536, 5, 5]               0
#      BatchNorm2d-232           [-1, 1536, 5, 5]           3,072
#     DwsConvBlock-233           [-1, 1536, 5, 5]               0
#             ReLU-234           [-1, 1536, 5, 5]               0
#           Conv2d-235           [-1, 1536, 5, 5]          13,824
#           Conv2d-236           [-1, 2048, 5, 5]       3,145,728
#          DwsConv-237           [-1, 2048, 5, 5]               0
#      BatchNorm2d-238           [-1, 2048, 5, 5]           4,096
#     DwsConvBlock-239           [-1, 2048, 5, 5]               0
#             ReLU-240           [-1, 2048, 5, 5]               0
# AdaptiveAvgPool2d-241           [-1, 2048, 1, 1]               0
# XceptionFinalBlock-242           [-1, 2048, 1, 1]               0
# ================================================================
# Total params: 20,806,952
# Trainable params: 20,806,952
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 209.43
# Params size (MB): 79.37
# Estimated Total Size (MB): 289.06
# ----------------------------------------------------------------

# %% [markdown]
# ### 2.2 Model Tuning

# %%
class Head(torch.nn.Module):
  def __init__(self, in_f, out_f):
    super(Head, self).__init__()
    
    self.f = torch.nn.Flatten()
    self.l = nn.Linear(in_f, 512)
    self.d = nn.Dropout(0.75)
    self.o = nn.Linear(512, out_f)
    self.b1 = nn.BatchNorm1d(in_f)
    self.b2 = nn.BatchNorm1d(512)
    self.r = nn.ReLU()

  def forward(self, x):
    x = self.f(x)
    x = self.b1(x)
    x = self.d(x)

    x = self.l(x)
    x = self.r(x)
    x = self.b2(x)
    x = self.d(x)

    out = self.o(x)
    return out

# %%
dir(torch.nn)
# Out:
# ['AdaptiveAvgPool1d',
#  'AdaptiveAvgPool2d',
#  'AdaptiveAvgPool3d',
#  'AdaptiveLogSoftmaxWithLoss',
#  'AdaptiveMaxPool1d',
#  'AdaptiveMaxPool2d',
#  'AdaptiveMaxPool3d',
#  'AlphaDropout',
#  'AvgPool1d',
#  'AvgPool2d',
#  'AvgPool3d',
#  'BCELoss',
#  'BCEWithLogitsLoss',
#  'BatchNorm1d',
#  'BatchNorm2d',
#  'BatchNorm3d',
#  'Bilinear',
#  'CELU',
#  'CTCLoss',
#  'ConstantPad1d',
#  'ConstantPad2d',
#  'ConstantPad3d',
#  'Container',
#  'Conv1d',
#  'Conv2d',
#  'Conv3d',
#  'ConvTranspose1d',
#  'ConvTranspose2d',
#  'ConvTranspose3d',
#  'CosineEmbeddingLoss',
#  'CosineSimilarity',
#  'CrossEntropyLoss',
#  'CrossMapLRN2d',
#  'DataParallel',
#  'Dropout',
#  'Dropout2d',
#  'Dropout3d',
#  'ELU',
#  'Embedding',
#  'EmbeddingBag',
#  'FeatureAlphaDropout',
#  'Flatten',
#  'Fold',
#  'FractionalMaxPool2d',
#  'FractionalMaxPool3d',
#  'GELU',
#  'GLU',
#  'GRU',
#  'GRUCell',
#  'GroupNorm',
#  'Hardshrink',
#  'Hardtanh',
#  'HingeEmbeddingLoss',
#  'Identity',
#  'InstanceNorm1d',
#  'InstanceNorm2d',
#  'InstanceNorm3d',
#  'KLDivLoss',
#  'L1Loss',
#  'LPPool1d',
#  'LPPool2d',
#  'LSTM',
#  'LSTMCell',
#  'LayerNorm',
#  'LeakyReLU',
#  'Linear',
#  'LocalResponseNorm',
#  'LogSigmoid',
#  'LogSoftmax',
#  'MSELoss',
#  'MarginRankingLoss',
#  'MaxPool1d',
#  'MaxPool2d',
#  'MaxPool3d',
#  'MaxUnpool1d',
#  'MaxUnpool2d',
#  'MaxUnpool3d',
#  'Module',
#  'ModuleDict',
#  'ModuleList',
#  'MultiLabelMarginLoss',
#  'MultiLabelSoftMarginLoss',
#  'MultiMarginLoss',
#  'MultiheadAttention',
#  'NLLLoss',
#  'NLLLoss2d',
#  'PReLU',
#  'PairwiseDistance',
#  'Parameter',
#  'ParameterDict',
#  'ParameterList',
#  'PixelShuffle',
#  'PoissonNLLLoss',
#  'RNN',
#  'RNNBase',
#  'RNNCell',
#  'RNNCellBase',
#  'RReLU',
#  'ReLU',
#  'ReLU6',
#  'ReflectionPad1d',
#  'ReflectionPad2d',
#  'ReplicationPad1d',
#  'ReplicationPad2d',
#  'ReplicationPad3d',
#  'SELU',
#  'Sequential',
#  'Sigmoid',
#  'SmoothL1Loss',
#  'SoftMarginLoss',
#  'Softmax',
#  'Softmax2d',
#  'Softmin',
#  'Softplus',
#  'Softshrink',
#  'Softsign',
#  'SyncBatchNorm',
#  'Tanh',
#  'Tanhshrink',
#  'Threshold',
#  'Transformer',
#  'TransformerDecoder',
#  'TransformerDecoderLayer',
#  'TransformerEncoder',
#  'TransformerEncoderLayer',
#  'TripletMarginLoss',
#  'Unfold',
#  'Upsample',
#  'UpsamplingBilinear2d',
#  'UpsamplingNearest2d',
#  'ZeroPad2d',
#  '_VF',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_reduction',
#  'functional',
#  'grad',
#  'init',
#  'intrinsic',
#  'modules',
#  'parallel',
#  'parameter',
#  'qat',
#  'quantized',
#  'utils']

# %%
class FCN(torch.nn.Module):
  def __init__(self, base, in_f):
    super(FCN, self).__init__()
    self.base = base
    self.h1 = Head(in_f, 1)
  
  def forward(self, x):
    x = self.base(x)
    return self.h1(x)

model = FCN(model, 2048)

# %% [markdown]
# ## 3. Model Training

# %% [markdown]
# ### 3.1 Train Functions

# %%
def criterion1(pred1, targets):
  l1 = F.binary_cross_entropy(F.sigmoid(pred1), targets)
  return l1

def train_model(epoch, optimizer, scheduler=None, history=None):
    model.train()
    total_loss = 0
    
    t = tqdm(train_loader)
    for i, (img_batch, y_batch) in enumerate(t):
        img_batch = img_batch.cuda().float()
        y_batch = y_batch.cuda().float()

        optimizer.zero_grad()

        out = model(img_batch)
        loss = criterion1(out, y_batch)

        total_loss += loss
        t.set_description(f'Epoch {epoch+1}/{n_epochs}, LR: %6f, Loss: %.4f'%(optimizer.state_dict()['param_groups'][0]['lr'],total_loss/(i+1)))

        if history is not None:
          history.loc[epoch + i / len(X), 'train_loss'] = loss.data.cpu().numpy()
          history.loc[epoch + i / len(X), 'lr'] = optimizer.state_dict()['param_groups'][0]['lr']

        loss.backward()
        optimizer.step()
        if scheduler is not None:
          scheduler.step()

def evaluate_model(epoch, scheduler=None, history=None):
    model.eval()
    loss = 0
    pred = []
    real = []
    with torch.no_grad():
        for img_batch, y_batch in val_loader:
            img_batch = img_batch.cuda().float()
            y_batch = y_batch.cuda().float()

            o1 = model(img_batch)
            l1 = criterion1(o1, y_batch)
            loss += l1
            
            for j in o1:
              pred.append(F.sigmoid(j))
            for i in y_batch:
              real.append(i.data.cpu())
    
    pred = [p.data.cpu().numpy() for p in pred]
    pred2 = pred
    pred = [np.round(p) for p in pred]
    pred = np.array(pred)
    acc = sklearn.metrics.recall_score(real, pred, average='macro')

    real = [r.item() for r in real]
    pred2 = np.array(pred2).clip(0.1, 0.9)
    kaggle = sklearn.metrics.log_loss(real, pred2)

    loss /= len(val_loader)
    
    if history is not None:
        history.loc[epoch, 'dev_loss'] = loss.cpu().numpy()
    
    if scheduler is not None:
      scheduler.step(loss)

    print(f'Dev loss: %.4f, Acc: %.6f, Kaggle: %.6f'%(loss,acc,kaggle))
    
    return loss

# %% [markdown]
# ### 3.2 Dataloaders

# %%
X, val_X, y, val_y = get_random_sampling(paths, y, val_paths, val_y)

print('There are '+str(y.count(1))+' fake train samples')
print('There are '+str(y.count(0))+' real train samples')
print('There are '+str(val_y.count(1))+' fake val samples')
print('There are '+str(val_y.count(0))+' real val samples')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 104890/104890 [02:58<00:00, 587.84it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 7366/7366 [00:08<00:00, 883.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 69534/69534 [03:31<00:00, 328.48it/s]
# There are 87848 fake train samples
# There are 81726 real train samples
# There are 6108 fake val samples
# There are 6108 real val samples

# %%
import albumentations
from albumentations.augmentations.transforms import ShiftScaleRotate, HorizontalFlip, Normalize, RandomBrightnessContrast, MotionBlur, Blur, GaussNoise, JpegCompression
train_transform = albumentations.Compose([
                                          ShiftScaleRotate(p=0.3, scale_limit=0.25, border_mode=1, rotate_limit=25),
                                          HorizontalFlip(p=0.2),
                                          RandomBrightnessContrast(p=0.3, brightness_limit=0.25, contrast_limit=0.5),
                                          MotionBlur(p=.2),
                                          GaussNoise(p=.2),
                                          JpegCompression(p=.2, quality_lower=50),
                                          Normalize()
])
val_transform = albumentations.Compose([
                                          Normalize()
])

train_dataset = ImageDataset(X, y, transform=train_transform)
val_dataset = ImageDataset(val_X, val_y, transform=val_transform)

# %%
nrow, ncol = 5, 6
fig, axes = plt.subplots(nrow, ncol, figsize=(20, 8))
axes = axes.flatten()
for i, ax in enumerate(axes):
    image, label = train_dataset[i]
    image = np.rollaxis(image, 0, 3)
    image = image*std + mean
    image = np.clip(image, 0., 1.)
    ax.imshow(image)
    ax.set_title(f'label: {label}')

# %% [markdown]
# ### 3.3 Train

# %%
import gc

history = pd.DataFrame()
history2 = pd.DataFrame()

torch.cuda.empty_cache()
gc.collect()

best = 1e10
n_epochs = 20
batch_size = 128

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

model = model.cuda()

optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, mode='min', factor=0.7, verbose=True, min_lr=1e-5)

for epoch in range(n_epochs):
    torch.cuda.empty_cache()
    gc.collect()

    train_model(epoch, optimizer, scheduler=None, history=history)
    
    loss = evaluate_model(epoch, scheduler=scheduler, history=history2)
    
    if loss < best:
      best = loss
      print(f'Saving best model...')
      torch.save(model.state_dict(), f'model.pth')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-b72454d76fcb> in <module>()
#      14 val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
#      15
# ---> 16 model = model.cuda()
#      17
#      18 optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in cuda(self, device)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     221                 # `with torch.no_grad():`
#     222                 with torch.no_grad():
# --> 223                     param_applied = fn(param)
#     224                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     225                 if should_use_set_data:
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in <lambda>(t)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# ~\Anaconda3\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     194             raise RuntimeError(
#     195                 "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 196         _check_driver()
#     197         torch._C._cuda_init()
#     198         _cudart = _load_cudart()
#
# ~\Anaconda3\lib\site-packages\torch\cuda\__init__.py in _check_driver()
#      99 Found no NVIDIA driver on your system. Please check that you
#     100 have an NVIDIA GPU and installed a driver from
# --> 101 http://www.nvidia.com/Download/index.aspx""")
#     102         else:
#     103             # TODO: directly link to the alternative bin that needs install
#
# AssertionError:
# Found no NVIDIA driver on your system. Please check that you
# have an NVIDIA GPU and installed a driver from
# http://www.nvidia.com/Download/index.aspx

# %%
history2.plot()
